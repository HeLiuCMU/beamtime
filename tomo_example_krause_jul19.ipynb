# %%
# check raw images

# %%
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py

# %%
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
proj = dxchange.reader.read_tiff_stack(fname='/home/s1c/krause_jul19/tomo/s1400poly1_tomo/s1400poly1_tomo_004713.tif',
                                       ind=range(4713,6184))
import h5py
hf = h5py.File('s1400poly1_tomo.h5', 'w')
hf.create_dataset('data', data=proj)
hf.close()
del proj

# %%
del proj

# %%
h5 = h5py.File('s1400poly1_tomo.h5','r')
data = h5['/data'][0,910:1480,:]
print(data.shape)
plt.imshow(data)
# Out:
# (570, 2048)

# %%
theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
# Out:
# [0.00000000e+00 4.36635532e-03 8.73271064e-03 ... 6.27445260e+00
#  6.27881895e+00 6.28318531e+00] (1440,)

# %%
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
proj = dxchange.reader.read_tiff_stack(fname='/home/s1c/krause_jul19/tomo/s1400poly2_tomo/s1400poly2_tomo_004713.tif',
                                       ind=range(78186,79656))
import h5py
hf = h5py.File('s1400poly2_tomo.h5', 'w')
hf.create_dataset('data', data=proj)
hf.close()
del proj

# %%
# find center
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py
rot_center = 966.796875
layerStart= 1200#910 #1200 #910  # 1200
layerEnd= 1210 #1480 #1210   #1480 # 1250
h5 = h5py.File('s1400poly2_tomo.h5','r')
data = h5['/data'][0,layerStart:layerEnd,:]
print(data.shape)
plt.imshow(data)

white = h5['/data'][-19:-10,layerStart:layerEnd,:].astype(np.float)
projNew = h5['/data'][11:-20,layerStart:layerEnd,:].astype(np.float)
dark = h5['/data'][-10:-2,layerStart:layerEnd,:].astype(np.float)

theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
white_median = np.median(white, axis=0)
dark_median = np.median(dark, axis=0)
projNew = tomopy.normalize(projNew, white_median, dark_median)
projNew = tomopy.minus_log(projNew)

#rot_center = tomopy.find_center(projPhase, theta, init=966, ind=0, tol=0.5)
print(rot_center)

recon = tomopy.recon(projNew, theta, center=rot_center, algorithm='gridrec')
recon = tomopy.remove_ring(recon)
absorp = tomopy.retrieve_phase(recon,pixel_size=0.000148,dist=0.5,energy=71.676)

dxchange.write_tiff_stack(absorp, 'new_recon_test_1/s1400poly1_')
# Out:
# (10, 2048)
# [0.00000000e+00 4.36939173e-03 8.73878346e-03 ... 6.27444652e+00
#  6.27881592e+00 6.28318531e+00] (1439,)
# 966.796875
# Reconstructing 8 slice groups with 8 master threads...

# %%
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
proj = dxchange.reader.read_tiff_stack(fname='/home/s1c/krause_jul19/tomo/s1400poly1_tomo/s1400poly1_tomo_004713.tif',
                                       ind=range(4713,6183))
import h5py
hf = h5py.File('s1400poly1_tomo.h5', 'w')
hf.create_dataset('data', data=proj)
hf.close()
del proj

# %%
# find center
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py
rot_center = 966.796875
layerStart= 910 #1200 #910  # 1200
layerEnd= 1480 #1210   #1480 # 1250
initial = 's1400poly1_tomo'
h5 = h5py.File(f'{initial}.h5','r')
data = h5['/data'][0,layerStart:layerEnd,:]
print(data.shape)
plt.imshow(data)

white = h5['/data'][-19:-10,layerStart:layerEnd,:].astype(np.float)
projNew = h5['/data'][10:(10+1441),layerStart:layerEnd,:].astype(np.float)
dark = h5['/data'][-9:-2,layerStart:layerEnd,:].astype(np.float)

plt.imshow(white[0,:,:])
plt.show()
plt.imshow(white[-1,:,:])
plt.show()
plt.imshow(dark[0,:,:])
plt.show()
plt.imshow(dark[-1,:,:])
plt.show()
plt.imshow(projNew[0,:,:])
plt.show()
plt.imshow(projNew[-1,:,:])
plt.show()

theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
white_median = np.median(white, axis=0)
dark_median = np.median(dark, axis=0)
projNew = tomopy.normalize(projNew, white_median, dark_median)
projNew = tomopy.minus_log(projNew)

#rot_center = tomopy.find_center(projPhase, theta, init=966, ind=0, tol=0.5)
print(rot_center)

recon = tomopy.recon(projNew, theta, center=rot_center, algorithm='gridrec')
recon = tomopy.remove_ring(recon)
absorp = tomopy.retrieve_phase(recon,pixel_size=0.000148,dist=0.5,energy=71.676)

dxchange.write_tiff_stack(absorp, f'{initial}_{layerStart}_{layerEnd}/{initial}_')
# Out:
# (570, 2048)
# [0.00000000e+00 4.36332313e-03 8.72664626e-03 ... 6.27445866e+00
#  6.27882198e+00 6.28318531e+00] (1441,)
# 966.796875
# Reconstructing 8 slice groups with 8 master threads...

# %%
# find center
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py
rot_center = 966.796875
layerStart= 910 #1200 #910  # 1200
layerEnd= 1480 #1210   #1480 # 1250
initial = 's1400_100_1_tomo'
startImgIdx = 152258
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
proj = dxchange.reader.read_tiff_stack(fname=f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_004713.tif',
                                       ind=range(startImgIdx,startImgIdx + 1471))
import h5py
hf = h5py.File(f'{initial}.h5', 'w')
hf.create_dataset('data', data=proj)
hf.close()
del proj


h5 = h5py.File(f'{initial}.h5','r')
data = h5['/data'][0,layerStart:layerEnd,:]
print(data.shape)
plt.imshow(data)

white = h5['/data'][-19:-10,layerStart:layerEnd,:].astype(np.float)
projNew = h5['/data'][10:(10+1441),layerStart:layerEnd,:].astype(np.float)
dark = h5['/data'][-9:-2,layerStart:layerEnd,:].astype(np.float)

plt.imshow(white[0,:,:])
plt.show()
plt.imshow(white[-1,:,:])
plt.show()
plt.imshow(dark[0,:,:])
plt.show()
plt.imshow(dark[-1,:,:])
plt.show()
plt.imshow(projNew[0,:,:])
plt.show()
plt.imshow(projNew[-1,:,:])
plt.show()

theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
white_median = np.median(white, axis=0)
dark_median = np.median(dark, axis=0)
projNew = tomopy.normalize(projNew, white_median, dark_median)
projNew = tomopy.minus_log(projNew)

#rot_center = tomopy.find_center(projPhase, theta, init=966, ind=0, tol=0.5)
print(rot_center)

recon = tomopy.recon(projNew, theta, center=rot_center, algorithm='gridrec')
recon = tomopy.remove_ring(recon)
absorp = tomopy.retrieve_phase(recon,pixel_size=0.000148,dist=0.5,energy=71.676)

dxchange.write_tiff_stack(absorp, f'{initial}_part1_{layerStart}_{layerEnd}/{initial}_')

# %% [markdown]
# # s1400_100_1_tomo

# %%
# find center
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py
rot_center = 966.796875
layerStart= 910 #1200 #910  # 1200
layerEnd= 1480 #1210   #1480 # 1250
initial = 's1400_100_1_tomo'
startImgIdx = 152258 + 1471
h5File = f'{initial}_2ndhalf.h5'
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
# proj = dxchange.reader.read_tiff_stack(fname=f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_004713.tif',
#                                        ind=range(startImgIdx,startImgIdx + 1471))
# import h5py

# h5 = h5py.File(h5File, 'w')
# h5.create_dataset('data', data=proj)
# h5.close()
# del proj


h5 = h5py.File(h5File,'r')
data = h5['/data'][0,layerStart:layerEnd,:]
print(data.shape)
plt.imshow(data)

white = h5['/data'][-19:-10,layerStart:layerEnd,:].astype(np.float)
projNew = h5['/data'][10:(10+1441),layerStart:layerEnd,:].astype(np.float)
dark = h5['/data'][-9:-2,layerStart:layerEnd,:].astype(np.float)

plt.imshow(white[0,:,:])
plt.show()
plt.imshow(white[-1,:,:])
plt.show()
plt.imshow(dark[0,:,:])
plt.show()
plt.imshow(dark[-1,:,:])
plt.show()
plt.imshow(projNew[0,:,:])
plt.show()
plt.imshow(projNew[-1,:,:])
plt.show()

theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
white_median = np.median(white, axis=0)
dark_median = np.median(dark, axis=0)
projNew = tomopy.normalize(projNew, white_median, dark_median)
projNew = tomopy.minus_log(projNew)

#rot_center = tomopy.find_center(projPhase, theta, init=966, ind=0, tol=0.5)
print(rot_center)

recon = tomopy.recon(projNew, theta, center=rot_center, algorithm='gridrec')

del projNew

recon = tomopy.remove_ring(recon)
absorp = tomopy.retrieve_phase(recon,pixel_size=0.000148,dist=0.5,energy=71.676)

dxchange.write_tiff_stack(absorp, f'{initial}_part2_{layerStart}_{layerEnd}/{initial}_')
# Out:
# (570, 2048)
# [0.00000000e+00 4.36332313e-03 8.72664626e-03 ... 6.27445866e+00
#  6.27882198e+00 6.28318531e+00] (1441,)
# 966.796875
# Reconstructing 12 slice groups with 12 master threads...

# %% [markdown]
# # s1350poly1

# %%
# find center
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py
rot_center = 966.796875
layerStart= 910 #1200 #910  # 1200
layerEnd= 1480 #1210   #1480 # 1250
initial = 's1350poly1_tomo'
startImgIdx = 257442   # index of first image.
h5File = f'{initial}.h5'
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
proj = dxchange.reader.read_tiff_stack(fname=f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_004713.tif',
                                       ind=range(startImgIdx,startImgIdx + 1471))
import h5py

h5 = h5py.File(h5File, 'w')
h5.create_dataset('data', data=proj)
h5.close()
del proj


h5 = h5py.File(h5File,'r')
data = h5['/data'][0,layerStart:layerEnd,:]
print(data.shape)
plt.imshow(data)

white = h5['/data'][-19:-10,layerStart:layerEnd,:].astype(np.float)
projNew = h5['/data'][10:(10+1441),layerStart:layerEnd,:].astype(np.float)
dark = h5['/data'][-9:-2,layerStart:layerEnd,:].astype(np.float)

plt.imshow(white[0,:,:])
plt.show()
plt.imshow(white[-1,:,:])
plt.show()
plt.imshow(dark[0,:,:])
plt.show()
plt.imshow(dark[-1,:,:])
plt.show()
plt.imshow(projNew[0,:,:])
plt.show()
plt.imshow(projNew[-1,:,:])
plt.show()

theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
white_median = np.median(white, axis=0)
dark_median = np.median(dark, axis=0)
projNew = tomopy.normalize(projNew, white_median, dark_median)
projNew = tomopy.minus_log(projNew)

#rot_center = tomopy.find_center(projPhase, theta, init=966, ind=0, tol=0.5)
print(rot_center)

recon = tomopy.recon(projNew, theta, center=rot_center, algorithm='gridrec')

del projNew

recon = tomopy.remove_ring(recon)
absorp = tomopy.retrieve_phase(recon,pixel_size=0.000148,dist=0.5,energy=71.676)

dxchange.write_tiff_stack(absorp, f'{initial}_part2_{layerStart}_{layerEnd}/{initial}_')
print('done')
########### check recon ##################
import tifffile
import glob
img = tifffile.imread(glob.glob(f'{initial}_part2_{layerStart}_{layerEnd}/{initial}_*')[0])
plt.imshow(img[500:1500,500:1500],vmin=-0.001,vmax=0.001)
# Out:
# (570, 2048)
# [0.00000000e+00 4.36332313e-03 8.72664626e-03 ... 6.27445866e+00
#  6.27882198e+00 6.28318531e+00] (1441,)
# 966.796875
# Reconstructing 12 slice groups with 12 master threads...

# %%
print('done')
########### check recon ##################
import tifffile
import glob
img = tifffile.imread(glob.glob(f'{initial}_part2_{layerStart}_{layerEnd}/{initial}_*')[0])
plt.imshow(img[500:1500,500:1500],vmin=-0.001,vmax=0.001)
# Out:
# done

# %%
import glob
import os

initial = 's1350_100_1_tomo'
idx = int(os.path.basename(sorted(glob.glob(f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_*.tif'))[0]).split('_')[-1].split('.')[0])
print(idx)
# Out:
# 331753

# %% [markdown]
# # s1350_100_1_tomo

# %%
# find center
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py
import glob
import os
import tifffile

rot_center = 966.796875
layerStart= 910 #1200 #910  # 1200
layerEnd= 1480 #1210   #1480 # 1250
initial = 's1350_100_1_tomo'
startImgIdx = int(os.path.basename(sorted(glob.glob(f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_*.tif'))[0]).split('_')[-1].split('.')[0])
print(f'startImgIdx: {startImgIdx}')
h5File = f'{initial}.h5'
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
#################### tiff into hdf5 ####################
# proj = dxchange.reader.read_tiff_stack(fname=f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_004713.tif',
#                                        ind=range(startImgIdx,startImgIdx + 1471))
# import h5py

# h5 = h5py.File(h5File, 'w')
# h5.create_dataset('data', data=proj)
# h5.close()
# del proj
################# load data and check #######################

h5 = h5py.File(h5File,'r')
data = h5['/data'][0,layerStart:layerEnd,:]
print(data.shape)
plt.imshow(data)

white = h5['/data'][-19:-10,layerStart:layerEnd,:].astype(np.float)
projNew = h5['/data'][10:(10+1441),layerStart:layerEnd,:].astype(np.float)
dark = h5['/data'][-9:-2,layerStart:layerEnd,:].astype(np.float)

plt.imshow(white[0,:,:])
plt.show()
plt.imshow(white[-1,:,:])
plt.show()
plt.imshow(dark[0,:,:])
plt.show()
plt.imshow(dark[-1,:,:])
plt.show()
plt.imshow(projNew[0,:,:])
plt.show()
plt.imshow(projNew[-1,:,:])
plt.show()

#################### tomo recon #######################
theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
white_median = np.median(white, axis=0)
dark_median = np.median(dark, axis=0)
projNew = tomopy.normalize(projNew, white_median, dark_median)
projNew = tomopy.minus_log(projNew)
#rot_center = tomopy.find_center(projPhase, theta, init=966, ind=0, tol=0.5)
print(rot_center)

recon = tomopy.recon(projNew, theta, center=rot_center, algorithm='gridrec')

del projNew

recon = tomopy.remove_ring(recon)
recon = tomopy.retrieve_phase(recon,pixel_size=0.000148,dist=0.5,energy=71.676)
#################### output tiff stack ##################
dxchange.write_tiff_stack(recon, f'{initial}_{layerStart}_{layerEnd}/{initial}_')
del recon
print('done!')
print('done')
########### check recon ##################
import tifffile
import glob
img = tifffile.imread(glob.glob(f'{initial}_{layerStart}_{layerEnd}/{initial}_*')[0])
plt.imshow(img[500:1500,500:1500],vmin=-0.001,vmax=0.001)
# Out:
# startImgIdx: 331753
# (570, 2048)
# [0.00000000e+00 4.36332313e-03 8.72664626e-03 ... 6.27445866e+00
#  6.27882198e+00 6.28318531e+00] (1441,)
# 966.796875
# Reconstructing 12 slice groups with 12 master threads...
# done!
# done
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-ec482ae83099> in <module>
#      78 import tifffile
#      79 import glob
# ---> 80 img = tifffile.imread(glob.glob(f'{initial}_{layerStart}_{layerEnd}/{initial}_*')[0])
#      81 plt.imshow(img[500:1500,500:1500],vmin=-0.001,vmax=0.001)
#
# IndexError: list index out of range

# %%
import tifffile
import glob
img = tifffile.imread(glob.glob(f'{initial}_part2_{layerStart}_{layerEnd}/{initial}_*')[0])
plt.imshow(img[500:1500,500:1500],vmin=-0.001,vmax=0.001)

# %% [markdown]
# # s1400_100_2_tomo

# %%
# find center
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py
import glob
import os
import tifffile

rot_center = 966.796875
layerStart= 910 #1200 #910  # 1200
layerEnd= 1480 #1210   #1480 # 1250
initial = 's1400_100_2_tomo'
startImgIdx = int(os.path.basename(sorted(glob.glob(f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_*.tif'))[0]).split('_')[-1].split('.')[0])
print(f'startImgIdx: {startImgIdx}')
h5File = f'{initial}.h5'
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
#################### tiff into hdf5 ####################
proj = dxchange.reader.read_tiff_stack(fname=f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_004713.tif',
                                       ind=range(startImgIdx,startImgIdx + 1471))
import h5py

h5 = h5py.File(h5File, 'w')
h5.create_dataset('data', data=proj)
h5.close()
del proj
################# load data and check #######################

h5 = h5py.File(h5File,'r')
data = h5['/data'][0,layerStart:layerEnd,:]
print(data.shape)
plt.imshow(data)

white = h5['/data'][-19:-10,layerStart:layerEnd,:].astype(np.float)
projNew = h5['/data'][10:(10+1441),layerStart:layerEnd,:].astype(np.float)
dark = h5['/data'][-9:-2,layerStart:layerEnd,:].astype(np.float)

plt.imshow(white[0,:,:])
plt.show()
plt.imshow(white[-1,:,:])
plt.show()
plt.imshow(dark[0,:,:])
plt.show()
plt.imshow(dark[-1,:,:])
plt.show()
plt.imshow(projNew[0,:,:])
plt.show()
plt.imshow(projNew[-1,:,:])
plt.show()

#################### tomo recon #######################
theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
white_median = np.median(white, axis=0)
dark_median = np.median(dark, axis=0)
projNew = tomopy.normalize(projNew, white_median, dark_median)
projNew = tomopy.minus_log(projNew)
#rot_center = tomopy.find_center(projPhase, theta, init=966, ind=0, tol=0.5)
print(rot_center)

recon = tomopy.recon(projNew, theta, center=rot_center, algorithm='gridrec')

del projNew

recon = tomopy.remove_ring(recon)
recon = tomopy.retrieve_phase(recon,pixel_size=0.000148,dist=0.5,energy=71.676)
#################### output tiff stack ##################
dxchange.write_tiff_stack(recon, f'{initial}_{layerStart}_{layerEnd}/{initial}_')
del recon
print('done!')
print('done')
########### check recon ##################
import tifffile
import glob
img = tifffile.imread(glob.glob(f'{initial}_{layerStart}_{layerEnd}/{initial}_*')[0])
plt.imshow(img[500:1500,500:1500],vmin=-0.001,vmax=0.001)
# Out:
# startImgIdx: 369707
# (570, 2048)
# [0.00000000e+00 4.36332313e-03 8.72664626e-03 ... 6.27445866e+00
#  6.27882198e+00 6.28318531e+00] (1441,)
# 966.796875
# Reconstructing 12 slice groups with 12 master threads...
# done!
# done

# %%
# find center
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py
import glob
import os
import tifffile

rot_center = 966.796875
layerStart= 910 #1200 #910  # 1200
layerEnd= 1480 #1210   #1480 # 1250
initial = 's1400_100_2_tomo'
startImgIdx = int(os.path.basename(sorted(glob.glob(f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_*.tif'))[0]).split('_')[-1].split('.')[0])
startImgIdx += 1471
print(f'startImgIdx: {startImgIdx}')
h5File = f'{initial}.h5'
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
#################### tiff into hdf5 ####################
proj = dxchange.reader.read_tiff_stack(fname=f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_004713.tif',
                                       ind=range(startImgIdx,startImgIdx + 1471))
import h5py

h5 = h5py.File(h5File, 'w')
h5.create_dataset('data', data=proj)
h5.close()
del proj
################# load data and check #######################

h5 = h5py.File(h5File,'r')
data = h5['/data'][0,layerStart:layerEnd,:]
print(data.shape)
plt.imshow(data)

white = h5['/data'][-19:-10,layerStart:layerEnd,:].astype(np.float)
projNew = h5['/data'][10:(10+1441),layerStart:layerEnd,:].astype(np.float)
dark = h5['/data'][-9:-2,layerStart:layerEnd,:].astype(np.float)

plt.imshow(white[0,:,:])
plt.show()
plt.imshow(white[-1,:,:])
plt.show()
plt.imshow(dark[0,:,:])
plt.show()
plt.imshow(dark[-1,:,:])
plt.show()
plt.imshow(projNew[0,:,:])
plt.show()
plt.imshow(projNew[-1,:,:])
plt.show()

#################### tomo recon #######################
theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
white_median = np.median(white, axis=0)
dark_median = np.median(dark, axis=0)
projNew = tomopy.normalize(projNew, white_median, dark_median)
projNew = tomopy.minus_log(projNew)
#rot_center = tomopy.find_center(projPhase, theta, init=966, ind=0, tol=0.5)
print(rot_center)

recon = tomopy.recon(projNew, theta, center=rot_center, algorithm='gridrec')

del projNew

recon = tomopy.remove_ring(recon)
recon = tomopy.retrieve_phase(recon,pixel_size=0.000148,dist=0.5,energy=71.676)
#################### output tiff stack ##################
dxchange.write_tiff_stack(recon, f'{initial}_{layerStart}_{layerEnd}/{initial}_')
del recon
print('done!')
print('done')
########### check recon ##################
import tifffile
import glob
img = tifffile.imread(glob.glob(f'{initial}_{layerStart}_{layerEnd}/{initial}_*')[0])
plt.imshow(img[500:1500,500:1500],vmin=-0.001,vmax=0.001)
# Out:
# startImgIdx: 371178
# (570, 2048)
# [0.00000000e+00 4.36332313e-03 8.72664626e-03 ... 6.27445866e+00
#  6.27882198e+00 6.28318531e+00] (1441,)
# 966.796875
# Reconstructing 12 slice groups with 12 master threads...
# done!
# done

# %% [markdown]
# # s1400_110_1_tomo

# %%
# find center
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py
import glob
import os
import tifffile

rot_center = 966.796875
layerStart= 910 #1200 #910  # 1200
layerEnd= 1480 #1210   #1480 # 1250
initial = 's1400_110_1_tomo'
startImgIdx = int(os.path.basename(sorted(glob.glob(f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_*.tif'))[0]).split('_')[-1].split('.')[0])
print(f'startImgIdx: {startImgIdx}')
h5File = f'{initial}.h5'
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
#################### tiff into hdf5 ####################
proj = dxchange.reader.read_tiff_stack(fname=f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_004713.tif',
                                       ind=range(startImgIdx,startImgIdx + 1471))
import h5py

h5 = h5py.File(h5File, 'w')
h5.create_dataset('data', data=proj)
h5.close()
del proj
################# load data and check #######################

h5 = h5py.File(h5File,'r')
data = h5['/data'][0,layerStart:layerEnd,:]
print(data.shape)
plt.imshow(data)

white = h5['/data'][-19:-10,layerStart:layerEnd,:].astype(np.float)
projNew = h5['/data'][10:(10+1441),layerStart:layerEnd,:].astype(np.float)
dark = h5['/data'][-9:-2,layerStart:layerEnd,:].astype(np.float)

plt.imshow(white[0,:,:])
plt.show()
plt.imshow(white[-1,:,:])
plt.show()
plt.imshow(dark[0,:,:])
plt.show()
plt.imshow(dark[-1,:,:])
plt.show()
plt.imshow(projNew[0,:,:])
plt.show()
plt.imshow(projNew[-1,:,:])
plt.show()

#################### tomo recon #######################
theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
white_median = np.median(white, axis=0)
dark_median = np.median(dark, axis=0)
projNew = tomopy.normalize(projNew, white_median, dark_median)
projNew = tomopy.minus_log(projNew)
#rot_center = tomopy.find_center(projPhase, theta, init=966, ind=0, tol=0.5)
print(rot_center)

recon = tomopy.recon(projNew, theta, center=rot_center, algorithm='gridrec')

del projNew

recon = tomopy.remove_ring(recon)
recon = tomopy.retrieve_phase(recon,pixel_size=0.000148,dist=0.5,energy=71.676)
#################### output tiff stack ##################
dxchange.write_tiff_stack(recon, f'{initial}_{layerStart}_{layerEnd}/{initial}_')
del recon
print('done!')
print('done')
########### check recon ##################
import tifffile
import glob
img = tifffile.imread(glob.glob(f'{initial}_{layerStart}_{layerEnd}/{initial}_*')[0])
plt.imshow(img[500:1500,500:1500],vmin=-0.001,vmax=0.001)
# Out:
# startImgIdx: 457106
# (570, 2048)
# [0.00000000e+00 4.36332313e-03 8.72664626e-03 ... 6.27445866e+00
#  6.27882198e+00 6.28318531e+00] (1441,)
# 966.796875
# Reconstructing 12 slice groups with 12 master threads...
# done!
# done

# %% [markdown]
# # s1350_110_1_tomo

# %%
# find center
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py
import glob
import os
import tifffile

rot_center = 966.796875
layerStart= 910 #1200 #910  # 1200
layerEnd= 1480 #1210   #1480 # 1250
initial = 's1350_110_1_tomo'
startImgIdx = int(os.path.basename(sorted(glob.glob(f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_*.tif'))[0]).split('_')[-1].split('.')[0])
print(f'startImgIdx: {startImgIdx}')
h5File = f'{initial}.h5'
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
#################### tiff into hdf5 ####################
# proj = dxchange.reader.read_tiff_stack(fname=f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_004713.tif',
#                                        ind=range(startImgIdx,startImgIdx + 1471))
# import h5py

# h5 = h5py.File(h5File, 'w')
# h5.create_dataset('data', data=proj)
# h5.close()
# del proj
################# load data and check #######################

h5 = h5py.File(h5File,'r')
data = h5['/data'][0,layerStart:layerEnd,:]
print(data.shape)
plt.imshow(data)

white = h5['/data'][-19:-10,layerStart:layerEnd,:].astype(np.float)
projNew = h5['/data'][10:(10+1441),layerStart:layerEnd,:].astype(np.float)
dark = h5['/data'][-9:-2,layerStart:layerEnd,:].astype(np.float)

plt.imshow(white[0,:,:])
plt.show()
plt.imshow(white[-1,:,:])
plt.show()
plt.imshow(dark[0,:,:])
plt.show()
plt.imshow(dark[-1,:,:])
plt.show()
plt.imshow(projNew[0,:,:])
plt.show()
plt.imshow(projNew[-1,:,:])
plt.show()

#################### tomo recon #######################
theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
white_median = np.median(white, axis=0)
dark_median = np.median(dark, axis=0)
projNew = tomopy.normalize(projNew, white_median, dark_median)
projNew = tomopy.minus_log(projNew)
#rot_center = tomopy.find_center(projPhase, theta, init=966, ind=0, tol=0.5)
print(rot_center)

recon = tomopy.recon(projNew, theta, center=rot_center, algorithm='gridrec')

del projNew

recon = tomopy.remove_ring(recon)
recon = tomopy.retrieve_phase(recon,pixel_size=0.000148,dist=0.5,energy=71.676)
#################### output tiff stack ##################
dxchange.write_tiff_stack(recon, f'{initial}_{layerStart}_{layerEnd}/{initial}_')
del recon
print('done!')
print('done')
########### check recon ##################
import tifffile
import glob
img = tifffile.imread(glob.glob(f'{initial}_{layerStart}_{layerEnd}/{initial}_*')[0])
plt.imshow(img[500:1500,500:1500],vmin=-0.001,vmax=0.001)
# Out:
# startImgIdx: 531254
# (570, 2048)
# [0.00000000e+00 4.36332313e-03 8.72664626e-03 ... 6.27445866e+00
#  6.27882198e+00 6.28318531e+00] (1441,)
# 966.796875
# Reconstructing 12 slice groups with 12 master threads...
# done!
# done

# %% [markdown]
# # s1400poly3_control_tomo

# %%
# find center
import dxchange
import matplotlib.pyplot as plt
import numpy as np
import tomopy
import h5py
import glob
import os
import tifffile

rot_center = 966.796875
layerStart= 910 #1200 #910  # 1200
layerEnd= 1480 #1210   #1480 # 1250
initial = 's1400poly3_control_tomo'
startImgIdx = int(os.path.basename(sorted(glob.glob(f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_*.tif'))[0]).split('_')[-1].split('.')[0])
print(f'startImgIdx: {startImgIdx}')
h5File = f'{initial}.h5'
# save as h5py
#ind=range(4713,6184),)
# 1471 images

#0-9, white
#last10: dark
#################### tiff into hdf5 ####################
proj = dxchange.reader.read_tiff_stack(fname=f'/media/heliu/Seagate Backup Plus Drive/krause_jul19/tomo/{initial}/{initial}_004713.tif',
                                       ind=range(startImgIdx,startImgIdx + 1471))
import h5py

h5 = h5py.File(h5File, 'w')
h5.create_dataset('data', data=proj)
h5.close()
del proj
################# load data and check #######################

h5 = h5py.File(h5File,'r')
data = h5['/data'][0,layerStart:layerEnd,:]
print(data.shape)
plt.imshow(data)

white = h5['/data'][-19:-10,layerStart:layerEnd,:].astype(np.float)
projNew = h5['/data'][10:(10+1441),layerStart:layerEnd,:].astype(np.float)
dark = h5['/data'][-9:-2,layerStart:layerEnd,:].astype(np.float)

plt.imshow(white[0,:,:])
plt.show()
plt.imshow(white[-1,:,:])
plt.show()
plt.imshow(dark[0,:,:])
plt.show()
plt.imshow(dark[-1,:,:])
plt.show()
plt.imshow(projNew[0,:,:])
plt.show()
plt.imshow(projNew[-1,:,:])
plt.show()

#################### tomo recon #######################
theta = tomopy.angles(projNew.shape[0])*2
print(theta,theta.shape)
white_median = np.median(white, axis=0)
dark_median = np.median(dark, axis=0)
projNew = tomopy.normalize(projNew, white_median, dark_median)
projNew = tomopy.minus_log(projNew)
#rot_center = tomopy.find_center(projPhase, theta, init=966, ind=0, tol=0.5)
print(rot_center)

recon = tomopy.recon(projNew, theta, center=rot_center, algorithm='gridrec')

del projNew

recon = tomopy.remove_ring(recon)
recon = tomopy.retrieve_phase(recon,pixel_size=0.000148,dist=0.5,energy=71.676)
#################### output tiff stack ##################
dxchange.write_tiff_stack(recon, f'{initial}_{layerStart}_{layerEnd}/{initial}_')
del recon
print('done!')
print('done')
########### check recon ##################
import tifffile
import glob
img = tifffile.imread(glob.glob(f'{initial}_{layerStart}_{layerEnd}/{initial}_*')[0])
plt.imshow(img[500:1500,500:1500],vmin=-0.001,vmax=0.001)
# Out:
# startImgIdx: 626326
# (570, 2048)
# [0.00000000e+00 4.36332313e-03 8.72664626e-03 ... 6.27445866e+00
#  6.27882198e+00 6.28318531e+00] (1441,)
# 966.796875
# Reconstructing 12 slice groups with 12 master threads...
# done!
# done
